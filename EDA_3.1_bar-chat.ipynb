# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
path=r"C:\Users\DELL\Documents\NareshIT\EDA\Data File\Visadataset.csv"
visa_df3=pd.read_csv(path)
visa_df3
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df3.select_dtypes(include='object').columns
num_columns=visa_df3.select_dtypes(exclude='object').columns
cat_columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols=['continent','no_of_employees']
visa_df3[cols]
# Out:
#       continent  no_of_employees
# 0          Asia            14513
# 1          Asia             2412
# 2          Asia            44444
# 3          Asia               98
# 4        Africa             1082
# ...         ...              ...
# 25475      Asia             2601
# 25476      Asia             3274
# 25477      Asia             1121
# 25478      Asia             1918
# 25479      Asia             3195
#
# [25480 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.bar('continent','no_of_employees',data=visa_df3)

plt.title("Bar chart")
plt.xlabel("continent")
plt.ylabel("no_of_employees")
plt.show()

# %%
cols=['no_of_employees','education_of_employee']
visa_df3[cols]
# Out:
#        no_of_employees education_of_employee
# 0                14513           High School
# 1                 2412              Master's
# 2                44444            Bachelor's
# 3                   98            Bachelor's
# 4                 1082              Master's
# ...                ...                   ...
# 25475             2601            Bachelor's
# 25476             3274           High School
# 25477             1121              Master's
# 25478             1918              Master's
# 25479             3195            Bachelor's
#
# [25480 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.bar('no_of_employees','education_of_employee',data=visa_df3)

plt.title("Bar chart")
plt.xlabel('no_of_employee')
plt.ylabel("education_of_employees")
plt.show()
